# %%
import datetime
from random import randint

# %%
randint(1, 10)
# Out:
# 3

# %%
# help(datetime.date) chusmear
unafecha = datetime.date(2026,8,13)
print(unafecha)
# Out:
# 2026-08-13

# %%
# datetime.date(2025,2,29) tira ValueError
unafecha.weekday()
# Out:
# 3

# %%
for i in range(10, 18):
    print(i, 'dayofweek', datetime.date(2026,8,i).weekday())
# Out:
# 10 dayofweek 0
# 11 dayofweek 1
# 12 dayofweek 2
# 13 dayofweek 3
# 14 dayofweek 4
# 15 dayofweek 5
# 16 dayofweek 6
# 17 dayofweek 0

# %%
datetime.date(2007,5,24).weekday()
# Out:
# 3

# %%
datetime.date.today()
# Out:
# datetime.date(2026, 8, 13)

# %%
datetime.datetime(2026,8,13,14,22)
# Out:
# datetime.datetime(2026, 8, 13, 14, 22)

# %%
fechayhora = datetime.datetime(2026,8,13)

# %%
fechayhora.month
# Out:
# 8

# %%
fechayhora.hour
# Out:
# 0

# %%
fechayhora.second
# Out:
# 0

# %%
fechaya = datetime.datetime.now()

# %%
fechaya.microsecond
# Out:
# 656617

# %%
unodeagosto = datetime.date(2026,8,1)

# %%
#help(datetime.timedelta) ver que son argumento nombrados
# |  timedelta(days=0, seconds=0, microseconds=0, milliseconds=0, minutes=0, hours=0, weeks=0)
intervalo = datetime.timedelta(days=1)

# %%
unodeagosto + intervalo
# Out:
# datetime.date(2026, 8, 2)

# %%
unodeagosto + datetime.timedelta(weeks=4)
# Out:
# datetime.date(2026, 8, 29)

# %%
# convirtiendo fechas a strings y viceversa
fechastring = '13/08/2026'
print(fechastring)
# Out:
# 13/08/2026

# %%
fechayhora
# Out:
# datetime.datetime(2026, 8, 13, 0, 0)

# %%
fechayhora.strftime("%d/%m/%Y")
# Out:
# '13/08/2026'

# %%
datetime.date.strptime('Hoy es 13 del 8 de 2026',"Hoy es %d del %m de %Y")
# Out:
# datetime.date(2026, 8, 13)

# %%
fechayhora.timestamp()
# Out:
# 1786590000.0

# %%
datetime.datetime.fromtimestamp(0)
# Out:
# datetime.datetime(1969, 12, 31, 21, 0)
