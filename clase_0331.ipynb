# %%
lista = [10, 4, -2, 1]
for i in lista:
    print(i)
    print("hola")
# Out:
# 10
# hola
# 4
# hola
# -2
# hola
# 1
# hola

# %%
for i in range(len(lista)):
    print(i, lista[i])
# Out:
# 0 10
# 1 4
# 2 -2
# 3 1

# %%
# estructa de control while "mientras"
# while condición: 
#      hacé tal cosa

j = 0
while j < 5:
    print(j)
    j = j + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
j = 0
while j < 5:
    print(j)
    j += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n = 10
while True:
    print(n)
    n = n - 3
    if n < 0:
        break
# Out:
# 10
# 7
# 4
# 1

# %%
while False:
    print("esto nunca se va a imprimir")

# %%
condicion = True
while condicion:
    print("acá estamos")
    condicion = False
# Out:
# acá estamos

# %%
for i in range(4):
    # pass
print("hola mundo")
# Out:
#   Cell In[15], line 3
#     print("hola mundo")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
# pass sirve para indentar
for i in range(4):
    if i%2:
        print(i)
    else:
        pass
print("hola mundo")
# Out:
# 1
# 3
# hola mundo

# %%
for i in range(10):
    if i%2:
        continue
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(10):
    if i == 5:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# operaciones que devuelven verdadero o falso:
print(4 == 4)
print(1 > 2)
# Out:
# True
# False

# %%
print(1 != 2)
# Out:
# True

# %%
print(2 != 2)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(True and False)
# Out:
# False

# %%
(1>2) or (3==3)
# Out:
# True

# %%
for i in range(10):
    if not i%2:
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
# generar lista de 12 números
# enteros entre 0 y 9 al azar
import random   
#random.randint(minimo, máximo)   (ambos extremos incluidos)
for i in range(10):
    print(random.randint(0,9), end='-')
# Out:
# 2-6-2-1-2-1-5-7-3-0-

# %%
lista = []
for i in range(10):
    lista.append(random.randint(0,9))
lista
# Out:
# [3, 7, 8, 5, 8, 2, 9, 5, 1, 5]

# %%
'-'.join(str(lista))
# Out:
# '[-3-,- -7-,- -8-,- -5-,- -8-,- -2-,- -9-,- -5-,- -1-,- -5-]'

# %%
str(lista)
# Out:
# '[3, 7, 8, 5, 8, 2, 9, 5, 1, 5]'

# %%
lista2 = []
for i in range(10):
    lista2.append(str(random.randint(0,9)))
'#'.join(lista2)  # el join acepta colecciones de strings
# Out:
# '4#4#7#5#3#7#4#9#3#1'

# %%
'#'.join('esto es una colección de strings')
# Out:
# 'e#s#t#o# #e#s# #u#n#a# #c#o#l#e#c#c#i#ó#n# #d#e# #s#t#r#i#n#g#s'

# %%
# posiciones pares de una lista
lista[::2]   #con slicing
# Out:
# [2, 4, 2, 1, 2]

# %%
# posiciones pares con while
contador = 0
while contador < len(lista):
    print(contador, lista[contador])
    contador += 2
# Out:
# 0 2
# 2 4
# 4 2
# 6 1
# 8 2

# %%
# implementación de la estructura do - while de C
condicion = False
while True:
    #lo que está acá se ejecuta al menos una vez
    print("acá estoy!")
    if not condicion:
        break
# Out:
# acá estoy!

# %%
lista=[]
for i in range(100):
    lista = lista + [random.randint(0,5)]
lista[:10]
# Out:
# [3, 4, 5, 5, 1, 3, 5, 1, 0, 1]

# %%
frecuencia = 6*[0]   # de esta manera tengo [0, 0, 0, 0, 0, 0]
# cada valor de la lista deberá decir cuántas veces está
# el número que representa su posición
# en * lista*
for i in range(6):
    frecuencia[i] = lista.count(i)
frecuencia
# Out:
# [16, 13, 15, 23, 22, 11]

# %%
['manzana', 'banana', 'banana', 'naranja'].count('pera')
# Out:
# 0

# %%
['manzana', 'banana', 'banana', 'naranja'].count('banana')
# Out:
# 2

# %%
frecuencia = [0, 0, 0, 0, 0, 0]
for i in lista:
    frecuencia[i] += 1
frecuencia
# Out:
# [16, 13, 15, 23, 22, 11]

# %%
sum(frecuencia)
# Out:
# 100

# %% [raw]
# 0: *************
# 1: ******
# 2: ****************
# 3: *************************
# 4: *******
# 5: ****************

# %%
for i in range(6):
    print('*', end='')
# Out:
# ******
