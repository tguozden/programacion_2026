# %% [markdown]
# # TP 5: Listas y Strings

# %% [markdown]
# ## 1
# ### Posiciones pares e impares
#
# Dada la siguiente lista, mostrá por pantalla primero los elementos en posiciones pares (0, 2, 4, ...) y luego los de posiciones impares (1, 3, 5, ...).

# %%
lista = [10, 20, 30, 40, 50, 60, 70, 80]

# Posiciones pares
pares = 
print('Pares:  ', pares)

# Posiciones impares
impares = 
print('Impares:', impares)

# %% [markdown]
# ## 2
# ### Lista en orden inverso
#
# Mostrá la siguiente lista en orden inverso. Intentá hacerlo de dos formas distintas.

# %%
lista = [3, 1, 4, 1, 5, 9, 2, 6]

# Forma 1: slicing
invertida_1 = 
print(invertida_1)

# Forma 2: otro método
invertida_2 = 
print(invertida_2)

# %% [markdown]
# ## 3
# ### Mínimo de una lista
#
# Buscá el mínimo de la lista de dos formas:
# 1. Usando la función `min()`
# 2. Recorriendo la lista con un `for`
#
# Al final, compará que ambos resultados sean iguales.

# %%
numeros = [7, 3, 9, 1, 5, 8, 2, 6]

# Forma 1: con min()
minimo_builtin = 

# Forma 2: con un for
minimo_manual = numeros[0]   # arrancamos asumiendo que el primero es el mínimo
for n in numeros:
    # Tu código acá
    pass

print('min():', minimo_builtin)
print('manual:', minimo_manual)
print('¿Son iguales?', minimo_builtin == minimo_manual)

# %% [markdown]
# ## 4
# ### Máximo de una lista
#
# Igual que el ejercicio anterior, pero buscando el máximo.
# 1. Usando `max()`
# 2. Recorriendo la lista con un `for`
#
# Compará los resultados al final.

# %%
numeros = [7, 3, 9, 1, 5, 8, 2, 6]

# Forma 1: con max()
maximo_builtin = 

# Forma 2: con un for
maximo_manual = numeros[0]
for n in numeros:
    # Tu código acá
    pass

print('max():', maximo_builtin)
print('manual:', maximo_manual)
print('¿Son iguales?', maximo_builtin == maximo_manual)

# %% [markdown]
# ## 5
# ### Filtrar por rango
#
# Pedile al usuario dos números `n` y `m` de tipo float. Mostrá los elementos de la lista que sean mayores que `n` y menores que `m`.

# %%
lista = [1.5, 3.2, 7.8, 4.1, 9.0, 2.3, 6.6, 5.5]

n = float(input('Ingresá el valor mínimo (n): '))
m = float(input('Ingresá el valor máximo (m): '))

print(f'Elementos mayores que {n} y menores que {m}:')
for elemento in lista:
    # Tu código acá
    pass

# %% [markdown]
# ## 6
# ### ¿Está ordenada?
#
# Escribí un programa que guarde `True` en una variable si la lista está ordenada de menor a mayor, y `False` si no lo está. Mostrá el resultado al final.
#
# Probalo con las dos listas.

# %%
lista_ordenada   = [1, 3, 5, 7, 9, 11]
lista_desordenada = [1, 3, 2, 7, 9, 11]

def esta_ordenada(lista):
    ordenada = True
    for i in range(len(lista) - 1):
        # comparar cada elemento con el siguiente
        # Tu código acá
        pass
    return ordenada

print(esta_ordenada(lista_ordenada))    # debe dar True
print(esta_ordenada(lista_desordenada)) # debe dar False

# %% [markdown]
# ## 7
# ### Ordenar una lista (difícil)
#
# Ordená la lista de dos formas:
# 1. Usando `.sort()`
# 2. Sin usar `.sort()`: usando `.copy()`, `min()` y `.remove()` para construir una nueva lista ordenada paso a paso
#
# La idea del punto 2 es: agarrás el mínimo de la lista original, lo agregás a la nueva, lo eliminás de la original, y repetís hasta que no quede nada.

# %%
lista = [7, 3, 9, 1, 5, 8, 2, 6]

# Forma 1: con .sort()
lista_1 = lista.copy()
lista_1.sort()
print('Con .sort():', lista_1)

# Forma 2: manual con min() y remove()
lista_2 = lista.copy()   # copia para no destruir la original
ordenada = []

while len(lista_2) > 0:
    # Tu código acá
    pass

print('Manual:     ', ordenada)
print('¿Son iguales?', lista_1 == ordenada)

# %% [markdown]
# ## 8
# ### Mezclar dos listas ordenadas
#
# Dadas dos listas ya ordenadas, escribí un programa que las mezcle en una única lista ordenada, preservando el orden.
#
# No vale concatenarlas y ordenar el resultado, hay que intercalar los elementos comparándolos uno a uno.
#
# Ejemplo: `[1,5,9,12]` y `[2,4,7,10]` → `[1,2,4,5,7,9,10,12]`

# %%
lista_a = [1, 5, 9, 12]
lista_b = [2, 4, 7, 10]

mezclada = []
i = 0  # índice para lista_a
j = 0  # índice para lista_b

while i < len(lista_a) and j < len(lista_b):
    # Comparar lista_a[i] con lista_b[j]
    # agregar el menor a mezclada y avanzar ese índice
    # Tu código acá
    pass

# Agregar los elementos que sobren de cualquiera de las dos listas
mezclada = mezclada + lista_a[i:] + lista_b[j:]

print(mezclada)  # debe dar [1, 2, 4, 5, 7, 9, 10, 12]

# %% [markdown]
# ## 9
# ### Meseta más larga
#
# Escribí un programa que encuentre el índice de inicio y fin de la meseta más larga de una lista. Una meseta es una subsecuencia de elementos iguales consecutivos.
#
# Ejemplo: `lista = [1,3,3,1,1,7,7,7,7,4,5,5,4,4,4]`
# inicio `lista[5]`
# fin    `lista[8]`
#
# De esta manera puedo acceder a ellos con el slicing `lista[5:9]`
# *(Recuerden que el límite superior, en slicing, es el siguiente)*

# %%
lista = [1, 3, 3, 1, 1, 7, 7, 7, 7, 4, 5, 5, 4, 4, 4]

inicio_actual = 0
mejor_inicio = 0
mejor_fin = 1

for i in range(1, len(lista)):
    # Tu código acá
    pass

print(f'Meseta más larga: [{mejor_inicio}, {mejor_fin}]')  # debe dar [5, 9]
print(f'Elementos: {lista[mejor_inicio:mejor_fin]}')

# %% [markdown]
# ---
# ## Sección Strings
#
# Ingresá una cadena de caracteres. Los siguientes ejercicios trabajan sobre esa cadena.

# %%
cadena = input('Ingresá una cadena: ')

# %% [markdown]
# ## 10
# ### Longitud sin `len()`
#
# Calculá cuántos caracteres tiene la cadena **sin usar `len()`**.

# %%
contador = 0
for caracter in cadena:
    # Tu código acá
    pass

print('Longitud:', contador)

# %% [markdown]
# ## 11
# ### Contar palabras
#
# Contá cuántas palabras ingresó el usuario.

# %%
# Tu código acá

# %% [markdown]
# ## 12
# ### Frecuencia de caracteres
#
# Creá dos listas:
# - `l1`: los caracteres que aparecen en la cadena, sin repetir, en el orden en que aparecen
# - `l2`: la cantidad de veces que aparece cada caracter (en la misma posición que en `l1`)
#
# Ejemplo: `'papa frita'` → `l1 = ['p','a',' ','f','r','i','t']`, `l2 = [2,3,1,1,1,1,1]`

# %%
l1 = []
l2 = []

for caracter in cadena:
    if caracter not in l1:
        # caracter nuevo: agregarlo a l1 y arrancar conteo en l2
        # Tu código acá
        pass
    else:
        # caracter ya visto: incrementar su conteo en l2
        # Tu código acá
        pass

print('Caracteres:', l1)
print('Frecuencias:', l2)

# %% [markdown]
# ## 13
# ### Cadena invertida
#
# Creá una nueva cadena con los caracteres en orden inverso.

# %%
# Tu código acá

# %% [markdown]
# ## 14
# ### Palabras invertidas
#
# Creá una nueva cadena invirtiendo el orden de las palabras (no de los caracteres).
#
# Ejemplo: `'hola mundo bello'` → `'bello mundo hola'`

# %%
# Tu código acá

# %% [markdown]
# ## 15
# ### Separar letras del resto
#
# Creá dos cadenas a partir de la cadena ingresada:
# - `solo_letras`: solo los caracteres alfabéticos
# - `resto`: todos los demás (espacios, números, signos, etc.)
#
# Pista: el método `.isalpha()` devuelve `True` si un caracter es una letra.

# %%
solo_letras = ''
resto = ''

for caracter in cadena:
    # Tu código acá
    pass

print('Solo letras:', solo_letras)
print('Resto:      ', resto)

# %% [markdown]
# ## 16
# ### Ordenar alfabéticamente
#
# Tomá la lista de letras del ejercicio anterior y ordenala alfabéticamente.

# %%
lista_letras = list(solo_letras)

# Tu código acá

print(lista_letras)

# %% [markdown]
# ## 17
# ### ¿Entero o flotante?
#
# Pedile al usuario que ingrese un número (como string). Detectá si es un entero o un flotante.
#
# - Si es flotante, imprimilo con 3 decimales
# - Si es entero, imprimilo con ceros a la izquierda ocupando 10 lugares
#
# Ejemplo entero: `'32'` → `'0000000032'`
# Ejemplo flotante: `'3.14159'` → `'3.142'`
#
# Pistas: `.isdigit()` detecta si todos los caracteres son dígitos. El operador `in` puede buscar un caracter dentro de un string.

# %%
numero = input('Ingresá un número: ')

if '.' in numero:
    # Es flotante
    # Tu código acá
    pass
else:
    # Es entero
    # Tu código acá
    pass
