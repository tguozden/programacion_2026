# %%
# colecciones que conocemos
mitupla = (0,1,2)
cadenas = "hoy es jueves"
listas = [mitupla, cadenas, 1, 2, 3]
# las puedo recorrer
# for i in mitupla:
# for i in cadenas:
# for i in listas:
# y además están ordenadas

# %%
#nuevas colecciones!!!!
#conjuntos
mi_primer_conjunto = {1, 2, 3}
print(mi_primer_conjunto)
# Out:
# {1, 2, 3}

# %%
for i in mi_primer_conjunto:
    print(i)
# Out:
# 1
# 2
# 3

# %%
mi_primer_conjunto[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 mi_primer_conjunto[0]
#
# TypeError: 'set' object is not subscriptable

# %%
print({1, 2, 3, 3, 3, 3})
# Out:
# {1, 2, 3}

# %%
list("abc")  #recorre una colección y mete los elementos en una lista
# Out:
# ['a', 'b', 'c']

# %%
tuple([1, 2, 3])
# Out:
# (1, 2, 3)

# %%
set("abcccdeffffa")  # recorre un iterable o colección y lo mete en un conjunto
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %%
#diccionrios
{"etiqueta":"valor"}
# Out:
# {'etiqueta': 'valor'}

# %%
mi_dict = {"nombre":"juan carlos", "apellido":"ledesma"}
print(mi_dict)
# Out:
# {'nombre': 'juan carlos', 'apellido': 'ledesma'}

# %%
mi_dict['nombre']
# Out:
# 'juan carlos'

# %%
notas = {"lucas":10, "lauti":5, "caro":7}

# %%
notas["lucas"]
# Out:
# 10

# %%
notas.keys()
# Out:
# dict_keys(['lucas', 'lauti', 'caro'])

# %%
print(notas.keys())
# Out:
# dict_keys(['lucas', 'lauti', 'caro'])

# %%
for i in notas.keys():
    print(i)
# Out:
# lucas
# lauti
# caro

# %%
notas.values()
# Out:
# dict_values([10, 5, 7])

# %%
for i in notas:
    print(i, notas[i])
# Out:
# lucas 10
# lauti 5
# caro 7

# %%
mi_primer_conjunto
# Out:
# {1, 2, 3}

# %%
1 in mi_primer_conjunto
# Out:
# True
