# %% [markdown]
# # Examen – Introducción a la Computación
#
# Resolvé los 3 problemas que se presentan a continuación. Cada problema incluye ejemplos de entrada/salida para ayudarte a verificar tu solución.

# %% [markdown]
# ## Problema 1 – ¿Es palíndromo? (adaptado de TP6)
#
# Escribí una función `es_palindromo(cadena)` que devuelva `True` si la cadena se lee igual al derecho y al revés, ignorando espacios y mayúsculas.
#
# Ejemplo: `'Anita lava la tina'` → `True`

# %%
def es_palindromo(cadena):
    # Tu código acá
    pass


# Tests:
print(es_palindromo('Anita lava la tina'))  # True
print(es_palindromo('reconocer'))           # True
print(es_palindromo('python'))              # False

# %% [markdown]
# ## Problema 2 – Insertion sort (adaptado de TP7)
#
# Implementá `insertion_sort(lista)` que ordene la lista **inplace** de menor a mayor usando el algoritmo insertion sort.
#
# Para cada elemento desde el índice 1: guardalo en `clave`, desplazá hacia la derecha los elementos anteriores que sean mayores, e insertá `clave` en su posición correcta.

# %%
def insertion_sort(lista):
    # Tu código acá
    pass


# Tests:
a = [5, 3, 8, 1, 9, 2]
insertion_sort(a)
print(a)  # [1, 2, 3, 5, 8, 9]

b = [3, 3, 1, 3]
insertion_sort(b)
print(b)  # [1, 3, 3, 3]

# %% [markdown]
# ## Problema 3 – Cifrado César (adaptado de TP10)
#
# El cifrado César desplaza cada letra `n` posiciones en el abecedario. Con `n=3`: `'a'` → `'d'`, `'z'` → `'c'` (da la vuelta).
#
# Implementá `cesar(texto, n)` que cifre un string. Los caracteres que no son letras se dejan igual. Usá `ord()` y `chr()`.

# %%
def cesar(texto, n):
    # Tu código acá
    pass


# Tests:
print(cesar('hola', 3))          # 'krod'
print(cesar('xyz', 3))           # 'abc'
print(cesar('Hola, mundo!', 1))  # 'Ipmb, nvnep!'
print(cesar('krod', -3))         # 'hola'
