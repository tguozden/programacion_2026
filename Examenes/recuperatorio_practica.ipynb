# %% [markdown]
# # Práctica Recuperatorio

# %% [markdown]
# ---
# ## 1 (2 puntos)
# ### Frecuencia de longitudes
#
# La celda de abajo ya carga `asimov.txt` y genera una lista `palabras` con todas las palabras del texto.
#
# Escribí una función `frecuencia_longitudes(palabras)` que devuelva un diccionario donde cada clave es una longitud (cantidad de letras) y su valor es cuántas palabras tienen esa longitud.
#
# Resultado esperado (primeras filas):
# ```
# 1 letras: 334 palabras
# 2 letras: 1434 palabras
# 3 letras: 993 palabras
# ...
# ```

# %%
import re

with open('asimov.txt') as f:
    texto = f.read().lower()

palabras = re.findall(r'[a-záéíóúüñ]+', texto)
print(f'Total de palabras: {len(palabras)}')

# %%
def frecuencia_longitudes(palabras):
    # Tu código acá
    pass

freq = frecuencia_longitudes(palabras)
for longitud in sorted(freq):
    print(f'{longitud} letras: {freq[longitud]} palabras')

# %% [markdown]
# ---
# ## 2 (3 puntos)
# ### Parsear notas
#
# Es común recibir datos numéricos como cadenas de texto. Para trabajar con ellos hay que *parsearlos*: convertirlos a un tipo de datos adecuado.
#
# Por ejemplo, dada la cadena:
# ```python
# cadena = '7.5, 8.0\n6.0, 9.5'
# filas = cadena.split('\n')     # ['7.5, 8.0', '6.0, 9.5']
# xy = filas[0].split(', ')      # ['7.5', '8.0']
# tupla = (float(xy[0]), float(xy[1]))   # (7.5, 8.0)
# ```
#
# Cada fila representa las notas de un alumno en dos materias (Nota1, Nota2).
#
# Escribí una función `parsear(cadena)` que devuelva una lista de tuplas de floats.
#
# Resultado esperado:
# ```python
# [(7.5, 8.0), (6.0, 9.5), (8.5, 7.0), (5.0, 6.5), (9.0, 8.0), (7.0, 7.5)]
# ```

# %%
cadena = '''7.5, 8.0
6.0, 9.5
8.5, 7.0
5.0, 6.5
9.0, 8.0
7.0, 7.5'''

def parsear(cadena):
    # Tu código acá
    pass

notas = parsear(cadena)
print(notas)

# %% [markdown]
# ---
# ## 3 (4 puntos)
# ### Promedio general
#
# El promedio de un alumno con notas `(n1, n2)` es `(n1 + n2) / 2`.
#
# El promedio general del grupo es el promedio de todos esos promedios individuales.
#
# Escribí una función `promedio_general(notas)` que devuelva un único número float.
#
# Resultado esperado para la cadena de arriba:
# ```python
# 7.583
# ```

# %%
def promedio_general(notas):
    # Tu código acá
    pass

pg = promedio_general(notas)
print(f'Promedio general: {round(pg, 3)}')

# %% [markdown]
# ---
# ## 4 (6 puntos)
# ### Orden por promedio
#
# Escribí una función `orden_promedio(notas)` que devuelva una lista de enteros indicando el orden de los alumnos **de mayor a menor promedio**.
#
# Por ejemplo, si el alumno con mayor promedio es el de la posición `4`, el primer elemento de la lista será `4`.
#
# Resultado esperado para la cadena de arriba:
# ```python
# [4, 2, 1, 5, 0, 3]
# ```
#
# Pista: construí primero un diccionario `{tupla: promedio}` para poder consultar el promedio de cada alumno.

# %%
def orden_promedio(notas):
    # Tu código acá
    pass

orden = orden_promedio(notas)
print(orden)
print('Del mejor al peor promedio:')
for i in orden:
    n1, n2 = notas[i]
    print(f'  {i}: {notas[i]} -> {round((n1 + n2) / 2, 2)}')
