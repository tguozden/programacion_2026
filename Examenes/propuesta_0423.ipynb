# %% [markdown]
# # El detective de textos
#
# Tenemos un mensaje sospechoso. Vamos a analizarlo con las herramientas que ya tenemos.
#
# **Regla de hoy:** antes de escribir código, decí en voz alta cómo lo resolverías.

# %%
# El mensaje sospechoso
mensaje = 'Anita lava la tina y la tina lava a Anita'

# %% [markdown]
# ## 🔍 Caso 1: ¿Cuántas palabras tiene el mensaje?
#
# Pista: los strings tienen un método `.split()` que separa por espacios y devuelve una lista.

# %%
# Tu código acá

# %% [markdown]
# ## 🔍 Caso 2: ¿Cuál es la palabra más larga?
#
# Sin usar `max()`. Pensá cómo lo harías a mano: recorrés la lista y vas guardando la más larga que encontraste.

# %%
# Tu código acá

# %% [markdown]
# ## 🔍 Caso 3: ¿Cuántas veces aparece cada letra?
#
# Ignorá los espacios. Usá un diccionario donde las claves son letras y los valores son conteos.
#
# Antes de escribir código: ¿cómo lo harías en papel?

# %%
# Tu código acá

# %% [markdown]
# ## 🔍 Caso 4: ¿Cuál es la letra más frecuente?
#
# Usá el diccionario del caso anterior. Sin usar funciones mágicas, igual que el máximo de una lista.

# %%
# Tu código acá

# %% [markdown]
# ## 🔍 Caso 5: ¿Hay letras del abecedario que no aparecen?
#
# Pista: podés comparar las claves de tu diccionario con el string `'abcdefghijklmnopqrstuvwxyz'`.

# %%
abecedario = 'abcdefghijklmnopqrstuvwxyz'

# Tu código acá

# %% [markdown]
# ## 🔍 Caso 6: ¿El mensaje es un palíndromo?
#
# Ignorá espacios y mayúsculas. Escribí una función con type hints y docstring.

# %%
def es_palindromo(texto: str) -> bool:
    """
    Devuelve True si el texto es un palíndromo,
    ignorando espacios y mayúsculas.
    """
    # Tu código acá
    pass


print(es_palindromo(mensaje))              # ¿qué esperás?
print(es_palindromo('Anita lava la tina')) # True
print(es_palindromo('python'))             # False

# %% [markdown]
# ---
# ## 🧰 Bonus: empaquetar todo en funciones
#
# Si terminaste los casos anteriores, convertí el análisis completo en una función `analizar(texto)` que imprima todo el reporte de una sola llamada.

# %%
def analizar(texto: str) -> None:
    """
    Imprime un análisis completo del texto:
    cantidad de palabras, palabra más larga,
    letra más frecuente y si es palíndromo.
    """
    # Tu código acá
    pass


analizar(mensaje)

# %% [markdown]
# ---
# ## 🪄 Reveal final: ¿qué existe ya en Python para esto?
#
# Todo lo que hicieron a mano ya existe en la biblioteca estándar. Pero ahora entienden qué hace por dentro.

# %%
from collections import Counter

conteo = Counter(mensaje.replace(' ', '').lower())
print(conteo)
print('Más frecuente:', conteo.most_common(1))
