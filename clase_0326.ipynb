# %%
a = [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
for i in a:
    print(i, type(i).__name__)
# Out:
# 1 int
# 2 int
# 3 int
# a str
# [1, 2, 3] list
# (1, 2, 3) tuple

# %%
list(a)
# Out:
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
a
# Out:
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
# emular el comando list
b = []
# print(b + [1])
for i in a:
    b = b + [i]
print(a)
print(b)
print(list(a))
# Out:
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
a == b
# Out:
# True

# %%
tuple(a)
# Out:
# (1, 2, 3, 'a', [1, 2, 3], (1, 2, 3))

# %%
# las tuplas listas y string son colecciones
# indexables, es decir que están ordenadas
# slicing:
a[0]
# Out:
# 1

# %%
len(a)
# Out:
# 6

# %%
print(a[0], a[1], a[2], a[3], a[4], a[5])
# Out:
# 1 2 3 a [1, 2, 3] (1, 2, 3)

# %%
for i in range(6):
    print(f"elemento nro {i+1} es a[{i}]={a[i]}")
# Out:
# elemento nro 1 es a[0]=1
# elemento nro 2 es a[1]=2
# elemento nro 3 es a[2]=3
# elemento nro 4 es a[3]=a
# elemento nro 5 es a[4]=[1, 2, 3]
# elemento nro 6 es a[5]=(1, 2, 3)

# %%
a[5]
# Out:
# (1, 2, 3)

# %%
a[-1]
# Out:
# (1, 2, 3)

# %%
a[-2]
# Out:
# [1, 2, 3]

# %%
a[-5]
# Out:
# 2

# %%
a[-6]
# Out:
# 1

# %%
cadena = 'hola mundo'
cadena[0]
# Out:
# 'h'

# %%
cadena[-1]
# Out:
# 'o'

# %%
cadena[::2]
# Out:
# 'hl ud'

# %%
cadena[0:3]  # es lo mismo que cadena[:3]
# Out:
# 'hol'

# %%
print(len(cadena))
# Out:
# 10

# %%
cadena[3:]   # es lo mismo que cadena[3:10]
# Out:
# 'a mundo'

# %%
cadena[3:10]
# Out:
# 'a mundo'

# %%
cadena[3:9]
# Out:
# 'a mund'

# %%
cadena[3:-1]
# Out:
# 'a mund'

# %%
a
# Out:
# [1, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
a[0] = 100
a
# Out:
# [100, 2, 3, 'a', [1, 2, 3], (1, 2, 3)]

# %%
cadena[0] = 'j'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 cadena[0] = 'j'
#
# TypeError: 'str' object does not support item assignment

# %%
c = (1, 2, 3)
c[0]
# Out:
# 1

# %%
c[0] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 c[0] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
paises = ['Brasil', 'Chile', 'Argentina', 'Uruguay', 'Peru', 'Colombia', 'Bolivia']

# %%
for i in paises:
    print(f"el pais {i} tiene {len(i)} letras")
# Out:
# el pais Brasil tiene 6 letras
# el pais Chile tiene 5 letras
# el pais Argentina tiene 9 letras
# el pais Uruguay tiene 7 letras
# el pais Peru tiene 4 letras
# el pais Colombia tiene 8 letras
# el pais Bolivia tiene 7 letras

# %%
# ejercicio 2 tp4
original = ['rojo', 'verde', 'azul']

# Parte A: asignación directa
copia = original

# %%
original[0] = 'auto'

# %%
original
# Out:
# ['auto', 'verde', 'azul']

# %%
copia
# Out:
# ['auto', 'verde', 'azul']

# %%
"hola mundo".split()
# Out:
# ['hola', 'mundo']

# %%
"hola mundo".split('m')
# Out:
# ['hola ', 'undo']

# %%
himno='''Sean eternos los laureles
que supimos conseguir:
Coronados de gloria vivamos
O juremos con gloria morir. Oid ¡mortales! el grito sagrado:
¡Libertad, libertad, libertad!
Oid el ruido de rotas cadenas:
Ved en trono a la noble Igualdad. Se levanta a la faz de la tierra
Una nueva y gloriosa Nación:
Coronada su sien de laureles
Y a su planta rendido un León. Coro De los nuevos campeones los rostros
Marte mismo parece animar; '''

# %%
himno
# Out:
# 'Sean eternos los laureles\nque supimos conseguir:\nCoronados de gloria vivamos\nO juremos con gloria morir. Oid ¡mortales! el grito sagrado:\n¡Libertad, libertad, libertad!\nOid el ruido de rotas cadenas:\nVed en trono a la noble Igualdad. Se levanta a la faz de la tierra\nUna nueva y gloriosa Nación:\nCoronada su sien de laureles\nY a su planta rendido un León. Coro De los nuevos campeones los rostros\nMarte mismo parece animar; '

# %%
himno.split('\n')
# Out:
# ['Sean eternos los laureles',
#  'que supimos conseguir:',
#  'Coronados de gloria vivamos',
#  'O juremos con gloria morir. Oid ¡mortales! el grito sagrado:',
#  '¡Libertad, libertad, libertad!',
#  'Oid el ruido de rotas cadenas:',
#  'Ved en trono a la noble Igualdad. Se levanta a la faz de la tierra',
#  'Una nueva y gloriosa Nación:',
#  'Coronada su sien de laureles',
#  'Y a su planta rendido un León. Coro De los nuevos campeones los rostros',
#  'Marte mismo parece animar; ']

# %%
# métodos en listas
a+['otro lemento']
# Out:
# [100, 2, 3, 'a', [1, 2, 3], (1, 2, 3), 'otro lemento']

# %%
a.append('4')

# %%
a.index(2)
# Out:
# 1

# %%
nros = [4, 1, 2, 8]

# %%
nros.sort()

# %%
nros
# Out:
# [1, 2, 4, 8]

# %%
sorted([4, 1, 2, 8])
# Out:
# [1, 2, 4, 8]

# %%
sorted('hola mundo')
# Out:
# [' ', 'a', 'd', 'h', 'l', 'm', 'n', 'o', 'o', 'u']

# %%
a.reverse()

# %%
a
# Out:
# ['4', (1, 2, 3), [1, 2, 3], 'a', 3, 2, 100]

# %%
'$'.join(('hola'))
# Out:
# 'h$o$l$a'
