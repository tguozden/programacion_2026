# %%
#estructuras de control


#for

for i in range(4):
    print(i, end = '-')
print()  # cambio de línea
for i in range(1,5):
    print(i, end = '-')
print()  # cambio de línea
for i in range(1, 10, 2):
    print(i, end = '-')
print()  # cambio de línea

cadena = 'hola mundo!'
for i in cadena:
    print(i, end = '-')
print()  # cambio de línea
# Out:
# 0-1-2-3-
# 1-2-3-4-
# 1-3-5-7-9-
# h-o-l-a- -m-u-n-d-o-!-

# %%
condicion = True
while condicion:
    print('hola! estoy en el scope del while')
    condicion = False
# Out:
# hola! estoy en el scope del while

# %%
temp = 15
if temp < 6:
    print('hace mucho frío')
elif temp >=6 and temp < 15:
    print('hace frío pero no tanto')
else:
    print('no hace frío')
# Out:
# no hace frío

# %%
# break continue pass

for i in range(10):
    print(i, end='-')
    if i==4:
        break
# Out:
# 0-1-2-3-4-

# %%
# continue:
for i in range(10):  
    if i==4:
        continue
    print(i, end='-')
# Out:
# 0-1-2-3-5-6-7-8-9-

# %%
# pass
for i in range(4):
    pass
print('qué miran')
# Out:
# qué miran

# %%
temp = 4
if temp >10:
    print('tal cosa')
else:
    # print('tal otra')
    pass

# %%
#pistas sobre el tipo de datos 
#en la definición de funciones

def elevaalcuadrado(n: int) -> int:
    ''' este es un texto
    que ponemos adelante de la función
    y que queda como documento de lo que hace la misma 
    '''
    return n*n
x = 3
print(f'{x} al cuadrado es {elevaalcuadrado(x)}')
# Out:
# 3 al cuadrado es 9

# %%
help(elevaalcuadrado)
# Out:
# Help on function elevaalcuadrado in module __main__:
#
# elevaalcuadrado(n: int) -> int
#     este es un texto
#     que ponemos adelante de la función
#     y que queda como documento de lo que hace la misma

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
parrafo = '''print(*args, sep=' ', end='\n', file=None, flush=False)
    Prints the values to a stream, or to sys.stdout by default.

    sep
      string inserted between values, default a space.
    end
      string appended after the last value, default a newline.
    file
      a file-like object (stream); defaults to the current sys.stdout.
    flush
      whether to forcibly flush the stream.'''

# %%
parrafo
# Out:
# "print(*args, sep=' ', end='\n', file=None, flush=False)\n    Prints the values to a stream, or to sys.stdout by default.\n\n    sep\n      string inserted between values, default a space.\n    end\n      string appended after the last value, default a newline.\n    file\n      a file-like object (stream); defaults to the current sys.stdout.\n    flush\n      whether to forcibly flush the stream."

# %%
print(parrafo)
# Out:
# print(*args, sep=' ', end='
# ', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
def holamundo()-> None:     #si la funcion no devuelve nada se usa None
    print('hola mundo!')
holamundo()
# Out:
# hola mundo!

# %%
#crear diccionarios
diccio1 = dict()
diccio2 = {}
print(type(diccio1), type(diccio2))
# Out:
# <class 'dict'> <class 'dict'>

# %%
diccio3 = {}
diccio3['arturo'] = 'duro'

# %%
diccio3
# Out:
# {'arturo': 'duro'}

# %%
diccio4 = {'azul': 'celeste'}

# %%
diccio4
# Out:
# {'azul': 'celeste'}

# %%
diccio3.update(diccio4)

# %%
diccio3
# Out:
# {'arturo': 'duro', 'azul': 'celeste'}

# %%
diccio3['azul']
# Out:
# 'celeste'

# %%
diccio3.get('arturo') # no la usa nadie!
# Out:
# 'duro'

# %%
diccio3.keys()
# Out:
# dict_keys(['arturo', 'azul'])

# %%
diccio3.values()
# Out:
# dict_values(['duro', 'celeste'])

# %%
for i,j in diccio3.items():
    print(i,j)
# Out:
# arturo duro
# azul celeste

# %%
diccio3.items()
# Out:
# dict_items([('arturo', 'duro'), ('azul', 'celeste')])

# %%
for i,j,in [('hola', 'que'),( 'tal','estamos')]:
    print(i,j)
# Out:
# hola que
# tal estamos
