# %%
nueva_var = [11, 22, 33]

# %%
nueva_var
# Out:
# [1, 2, 3]

# %%
# bucle for está bueno para recorrer listas

# para cada elemento en la lista
# nueva_var hacé lo siguiente
acumulame_aca = 0
for elemento in nueva_var:
    acumulame_aca = acumulame_aca + 1
    print(f"imprimo el elemento número {acumulame_aca} de la lista: {elemento}")
# Out:
# imprimo el elemento número 1 de la lista: 11
# imprimo el elemento número 2 de la lista: 22
# imprimo el elemento número 3 de la lista: 33

# %%
type('d')
# Out:
# str

# %%
type("a")
# Out:
# str

# %%
for i in range(10):
    print('hola')
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola

# %%
# factorizar un número cualquiera
#...

# averigüemos si un número es divisible por otro

a = 121
b = 11

print(121%11)
# Out:
# 0

# %%
a = 121
for i in range(1,a + 1):
    if a%i == 0:
        print(f'un divisor de {a} es ', i)
# Out:
# un divisor de 121 es  1
# un divisor de 121 es  11
# un divisor de 121 es  121

# %%
a = 123
esprimo = True
for i in range(2,a):
    if a%i == 0:
        esprimo = False
        print('no es primo!!')
        print('porque es divisible por ', i)
# Out:
# no es primo!!
# porque es divisible por  3
# no es primo!!
# porque es divisible por  41

# %%
condicion1 = True
condicion2 = True
if condicion1 and condicion2:
    print('ambas son verdaderas')
else:
    print('al menos una es falsa')
# Out:
# ambas son verdaderas

# %%
if condicion1:
    if condicion2:
        print('ambas condiciones son verdaderas')
# Out:
# ambas condiciones son verdaderas

# %%
if 1>2 and 3>0:
    print('esto nunca se va a imprimir')

# %%
if 4>2 and 3>0:
    print('esto se imprime')
# Out:
# esto se imprime

# %%
if 4>1 or False:
    print('esto se imprmie')
# Out:
# esto se imprmie

# %%
if 4:
    print('esto se imprimira??')
# Out:
# esto se imprimira??

# %%
if 0:
    print('y ahora?')

# %%
a = True
if not a:
    print('hola')

# %%
# aprendimos:
not, and, or
