# %%
print("hola mundo")
a="esto es texto"   # es una varible de tipo cadena de caracteres
b=12
# Out:
# hola mundo

# %%
var = 1.2

# %%
print( type(var)  )    # las funciones van con paréntesis
# Out:
# <class 'float'>

# %%
print(f"a vele:{a}", type(a)  )
# Out:
# a vele:esto es texto <class 'str'>

# %%
c = 12.0
type(c)
# Out:
# float

# %%
a
# Out:
# 'esto es texto'

# %%
c='a'
print(c, type(c))
print(c.capitalize())
# Out:
# a <class 'str'>
# A

# %%
'''
dir, que es otra función nativa,
me permite chusmear qué métodos (funciones)
tiene cada variable (objeto)
'''
dir(var)  

var.is_integer()
# Out:
# False

# %%
var=12.0
var.is_integer()
# Out:
# True

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
1 + 2
# Out:
# 3

# %%
1 + 2 * 3
# Out:
# 7

# %%
(1 + 2) * 3  # orden de precedencia
# Out:
# 9

# %%
3 * 2**2
# Out:
# 12

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2  # resultado entero de la operación
# Out:
# 1

# %%
#operador módulo
5%2
# Out:
# 1

# %%
print(0%4, 1%4, 2%4, 3%4, 4%4, 5%4)
# Out:
# 0 1 2 3 0 1
