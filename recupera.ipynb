# %% [markdown]
# ## 0
# ### Asimov
# Usando el texto `asimov.tx`, genere una lista con todas las palabras del texto (en minúscula) por un lado (ejercicio semana pasada). Luego genere una lista con los caracteres que no son letras, sin repetir.  (Aquellos que el método `.isalpha()` devuelve como `False`)
#
# Para imprimir los caracteres especiales con `print()` conviene pasarlos a formato representación con la función `repr()`
# Por ejemplo:
# ```python
# enter = '\n'
# print('así nomás:', enter)
# print('conviertiendo los strings a una representación formal', repr(enter))
#
# ```

# %% [markdown]
# ## Datos como texto
#
# Es común recibir datos numéricos como cadenas de texto. Para trabajar con ellos hay que *parsearlos*: convertirlos a un tipo de datos adecuado.
#
# Por ejemplo, dada la cadena de caracteres `cadena`:
# ```python
# cadena = '7.5, 8.0\n6.0, 9.5'
# filas = cadena.split('\n')     # ['7.5, 8.0', '6.0, 9.5']
# xy = filas[0].split(', ')      # ['7.5', '8.0']
# tupla = (float(xy[0]), float(xy[1]))   # (7.5, 8.0)
# ```
#
# Cada fila representa las notas de un alumno en dos materias (Nota1, Nota2).

# %% [markdown]
# ## 1
# ### Parsear
#
# Escribí una función `parsear(cadena)` que reciba la cadena de abajo y devuelva una lista de tuplas de floats.
#
# Resultado esperado:
# ```python
# [(7.5, 8.0), (6.0, 9.5), (8.5, 7.0), (5.0, 6.5), (9.0, 8.0), (7.0, 7.5)]
# ```

# %%
cadena = '''7.5, 8.0
6.0, 9.5
8.5, 7.0
5.0, 6.5
9.0, 8.0
7.0, 7.5'''

def parsear(cadena):
    # Tu código acá
    pass

notas = parsear(cadena)
print(notas)

# %% [markdown]
# ## 2
# ### Promedio por alumno
#
# El promedio de un alumno con notas `(n1, n2)` es:
#
# $$promedio = \frac{n1 + n2}{2}$$
#
# Escribí una función `promedios(notas)` que reciba la lista de tuplas y devuelva un diccionario donde cada clave es una tupla y su valor es el promedio del alumno.
#
# Resultado esperado:
# ```python
# {(7.5, 8.0): 7.75, (6.0, 9.5): 7.75, (8.5, 7.0): 7.75, ...}
# ```

# %%
def promedios(notas):
    # Tu código acá
    pass

proms = promedios(notas)
for alumno, p in proms.items():
    print(alumno, '->', round(p, 2))

# %% [markdown]
# ## 3
# ### Promedio general
#
# El promedio general del grupo es el promedio de todos los promedios individuales.
#
# Escribí una función `promedio_general(notas)` que devuelva un único número float con el promedio general.
#
# Resultado esperado para la cadena de arriba:
# ```python
# 7.583
# ```

# %%
def promedio_general(notas):
    # Tu código acá
    pass

pg = promedio_general(notas)
print(f'Promedio general: {round(pg, 3)}')

# %% [markdown]
# ## 4
# ### Orden por promedio
#
# Escribí una función `orden_promedio(notas)` que devuelva una lista de enteros indicando el orden de los alumnos **de mayor a menor promedio**.
#
# Por ejemplo, si el alumno con mayor promedio es el de la posición `4`, el primer elemento de la lista será `4`.
#
# Resultado esperado para la cadena de arriba:
# ```python
# [4, 2, 1, 5, 0, 3]
# ```
#
# Pista: podés usar el diccionario `proms` del ejercicio anterior.

# %%
def orden_promedio(notas):
    # Tu código acá
    pass

orden = orden_promedio(notas)
print(orden)
print('Del mejor al peor promedio:')
for i in orden:
    print(f'  {i}: {notas[i]} -> {round(proms[notas[i]], 2)}')
